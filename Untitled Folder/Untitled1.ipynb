# %%
a={1, 7, 3, 6, 9}
print("a=", a)

d = {1:'apple', 2:'cat',3:'food'}
print(d, type(d))
d[3]

Name="hello world"
print(Name[6])

3*"hello world"

Name="hello world"
s= Name+ " welcome"
s

A="hello world"
print("before upper:",A)
B=A.upper()
print("after upper:",B)

oldstring = 'I like fruits'
newstring = oldstring.replace('like', 'love')
print(newstring)

my_list = [_ for _ in 'abcdefghi']
print(my_list[-1])


a = [5, 10, 15, 20, 25, 30, 35, 40]
print(a)
print("a[2] = ", a[2])
print("[0:3] = ", a[0:3])
print("a[5:] = ", a[5:])
print("a[1:-2] =", a[1:-2])
print("a[:5]",a[:5])


print("a[1:5] = ", a[1:5])
print("a[5:] = ", a[5:])
print("a[:4] = ", a[:4])
print("a[7:] =", a[7:])

my_list[::3]
my_list[1::2]

my_list[5:3:-1]

my_list[-2:5:-1]

my_list[-1:-8:-3]


import numpy as np

a = np.array([1,2,3,5])
print (a)

import numpy as np
a = np.array([[1, 2], [3, 4]])
print (a)

import numpy as np
a = np.array([1, 2, 3, 4, 5], ndmin = 2)
print (a)
import numpy as np
a = np.array([1,2,3,5])
print (a)


dt = np.dtype('i1')
print(dt)

dt = np.dtype(np.int32)
print(dt)

dt = np.dtype([('age',np.int8)])
a =np.array([(10,),(20,),(30,)],dtype=dt)
print(a['age'])

import numpy as np
student = np.dtype([('name','S20'),('age','i1'),('marks','f4')])
print(student)
a = np.array([('abc', 21, 50),('xyz', 18, 75),('xy', 18, 75)])
print(a)
print(type(student))
# Out:
# a= {1, 3, 6, 7, 9}
# {1: 'apple', 2: 'cat', 3: 'food'} <class 'dict'>
# w
# before upper: hello world
# after upper: HELLO WORLD
# I love fruits
# i
# [5, 10, 15, 20, 25, 30, 35, 40]
# a[2] =  15
# [0:3] =  [5, 10, 15]
# a[5:] =  [30, 35, 40]
# a[1:-2] = [10, 15, 20, 25, 30]
# a[:5] [5, 10, 15, 20, 25]
# a[1:5] =  [10, 15, 20, 25]
# a[5:] =  [30, 35, 40]
# a[:4] =  [5, 10, 15, 20]
# a[7:] = [40]
# [1 2 3 5]
# [[1 2]
#  [3 4]]
# [[1 2 3 4 5]]
# [1 2 3 5]
# int8
# int32
# [10 20 30]
# [('name', 'S20'), ('age', 'i1'), ('marks', '<f4')]
# [['abc' '21' '50']
#  ['xyz' '18' '75']
#  ['xy' '18' '75']]
# <class 'numpy.dtype[void]'>
