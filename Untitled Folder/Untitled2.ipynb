# %%
print("hello world")
print(3*"\n")
print("welcome to world")
print("welcome to",end = ' ')
print("world",end = '!')
a=100
print(a)
print(1*"\n")
a=10
print(a)
print(1*"\n")
#print"hello, world!" to console 
print("hello, world!")
def double():
    """Function to double the value"""
    #return 3*num
print (double.__doc__)
def square():
    '''takes in a number n, returns ths square of n'''
print(square.__doc__) 
a=37
b=19.16
c=3+27j
print(int(b))
print(float(a))
print(complex(a))
print(complex(b))
print(complex(a, b))


x=(1==True)
y=(0==False)
a=True+7
b=False+100


print("x is",x)
print("y is",y)
print("a:",a)
print("b:",b)

x=[10,8,2003,'sound']
print(x)
a=[1,2,3]
print(a)
a[2]=4
print(a)


a={1, 7, 3, 6, 9}
print("a=", a)


d = {1:'apple', 2:'cat',3:'food'}
print(d, type(d))
d[3]
s = """Apple"""
print(s)
s = '''Apple'''
print(s)
s = 'Apple'
print(s)
s = "Apple"
print(s)
s = Apple
print(s)

Name="hello world"
print(Name[6])
import numpy as np
import numpy as np
# Out:
# hello world
#
#
#
#
# welcome to world
# welcome to world!100
#
#
# 10
#
#
# hello, world!
# Function to double the value
# takes in a number n, returns ths square of n
# 19
# 37.0
# (37+0j)
# (19.16+0j)
# (37+19.16j)
# x is True
# y is True
# a: 8
# b: 100
# [10, 8, 2003, 'sound']
# [1, 2, 3]
# [1, 2, 4]
# a= {1, 3, 6, 7, 9}
# {1: 'apple', 2: 'cat', 3: 'food'} <class 'dict'>
# Apple
# Apple
# Apple
# Apple
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 65>()
#      63 s = "Apple"
#      64 print(s)
# ---> 65 s = Apple
#      66 print(s)
#      68 Name="hello world"
#
# NameError: name 'Apple' is not defined
